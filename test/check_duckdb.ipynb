# %%
import duckdb
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)

con = duckdb.connect(r"D:\Practice\Scrapy\CrawlJob\DuckDB\warehouse.duckdb")
df = con.execute("SELECT * FROM bronze.jobs ORDER BY scraped_at DESC").fetchdf()

display(df)
# Out:
#                                                job_url  \
# 0    https://123job.vn/viec-lam/data-analyst-JD60ew...
# 1    https://123job.vn/viec-lam/data-analyst-3qZay1...
# 2    https://123job.vn/viec-lam/data-analyst-39Jm8o...
# 3    https://123job.vn/viec-lam/data-analyst-29ALPb...
# 4    https://123job.vn/viec-lam/data-analyst-smartp...
# ..                                                 ...
# 167  https://123job.vn/viec-lam/pricing-and-data-an...
# 168  https://123job.vn/viec-lam/cx-data-analyst-v91...
# 169  https://123job.vn/viec-lam/nhan-vien-phan-tich...
# 170  https://123job.vn/viec-lam/business-data-analy...
# 171  https://123job.vn/viec-lam/chuyen-vien-phan-ti...
#
#                                              job_title  \
# 0                                         Data Analyst
# 1                                         Data Analyst
# 2                                         Data Analyst
# 3                                         Data Analyst
# 4                            Data Analyst (Smartphone)
# ..                                                 ...
# 167                           Pricing and Data Analyst
# 168                                    CX Data Analyst
# 169       Nhân viên phân tích dữ liệu ( Data Analyst )
# 170                              Business Data Analyst
# 171  Chuyên viên phân tích dữ liệu Marketing - Data...
#
#                                           company_name          salary  \
# 0                   CÔNG TY CỔ PHẦN CÔNG NGHỆ ALPHAWAY   18 - 24 triệu
# 1    CÔNG TY TÀI CHÍNH TNHH MỘT THÀNH VIÊN QUỐC TẾ ...   Đang cập nhật
# 2                       CÔNG TY TNHH SMART-INGREDIENTS        25 triệu
# 3     CÔNG TY TNHH MỘT THÀNH VIÊN AN NINH MẠNG VIETTEL  2 - 10.1 triệu
# 4                                        OPPO VIỆT NAM   15 - 20 triệu
# ..                                                 ...             ...
# 167                           SEOUL SEMICONDUCTOR VINA   Đang cập nhật
# 168                   CÔNG TY CỔ PHẦN THẾ GIỚI DI ĐỘNG   Đang cập nhật
# 169         CÔNG TY CỔ PHẦN BẠCH MINH VEGA CORPORATION   Đang cập nhật
# 170         TẬP ĐOÀN CÔNG NGHIỆP - VIỄN THÔNG QUÂN ĐỘI         9 triệu
# 171                      BỆNH VIỆN ĐA KHOA PHƯƠNG ĐÔNG   Đang cập nhật
#
#                   location              job_type           job_industry  \
# 0                   Hà Nội        Toàn thời gian            IT phần mềm
# 1              Hồ Chí Minh  Nhân viên chính thức            IT phần mềm
# 2    Tân Bình, Hồ Chí Minh             FULL_TIME            IT phần mềm
# 3                   Hà Nội        Toàn thời gian            IT phần mềm
# 4              Hồ Chí Minh        Toàn thời gian            IT phần mềm
# ..                     ...                   ...                    ...
# 167                 Hà Nội         Đang cập nhật  Phát triển thị trường
# 168   Thủ Đức, Hồ Chí Minh         Đang cập nhật            IT phần mềm
# 169                 Hà Nội         Đang cập nhật  Phát triển thị trường
# 170                 Hà Nội        Toàn thời gian  Phát triển thị trường
# 171                 Hà Nội  Nhân viên chính thức  Phát triển thị trường
#
#               experience_level  education_level job_position  \
# 0                     Cập nhật             None  Trưởng Nhóm
# 1                    1 - 2 Năm          Đại học    Nhân Viên
# 2                     Cập nhật  bachelor degree    Nhân Viên
# 3                     Cập nhật             None    Nhân Viên
# 4                     Cập nhật             None    Nhân Viên
# ..                         ...              ...          ...
# 167                   Cập nhật             None    Nhân Viên
# 168                   Cập nhật             None    Nhân Viên
# 169                   Cập nhật             None    Nhân Viên
# 170  Không yêu cầu kinh nghiệm             None    Nhân Viên
# 171                  1 - 3 Năm          Đại học    Nhân Viên
#
#                                        job_description  \
# 0    - Đánh giá, lựa chọn nguồn dữ liệu phù hợp với...
# 1    Clean, classify, compile statistics, synthesiz...
# 2     Tiếp nhận và thu thập dữ liệu - Xác định xu h...
# 3    Xây dựng bộ KPI và các phương pháp đo lường hi...
# 4    - Analyze, process, and visualize market data ...
# ..                                                 ...
# 167  Position Overview This role will be responsibl...
# 168  Thống kê, phân tích và trực quan hóa dữ liệu p...
# 169                                               None
# 170  Phối hợp với các bên liên quan để phân tích và...
# 171  Tổng hợp dữ liệu và viết báo cáo; Dự báo và nắ...
#
#                                           requirements  \
# 0    Hiểu cách kết nối và truy vấn dữ liệu từ các n...
# 1    Work on financial company or installment servi...
# 2                                                 None
# 3    Có ít nhất 03 năm kinh nghiệm trong phân tích ...
# 4    - Proficient in Microsoft Excel, Power Query, ...
# ..                                                 ...
# 167                                               None
# 168  Biết sử dụng 1 trong các công cụ phân tích (ví...
# 169                                               None
# 170  Kiến thức về các loại CSDL (RDBMS, NoSQL, ...)...
# 171  Kiến thức về xử lý dữ liệu bị phân tán, dữ liệ...
#
#                                               benefits job_deadline  \
# 0    Trà, cafe, bánh kẹo miễn phí Thưởng lễ tết, th...   03/09/2025
# 1    Chế độ bảo hiểm, Du Lịch, Chế độ thưởng, Chăm ...   02/02/2025
# 2                                                 None   21/08/2025
# 3    Salary + Allowances: Giải thưởng nhân viên xuấ...   10/10/2025
# 4    • 13th- month salary. • Annual training, Activ...   11/10/2025
# ..                                                 ...          ...
# 167  Meals support (Breakfast, lunch), telephone al...   11/10/2025
# 168  Thời gian làm việc linh hoạt Mua Laptop ưu đãi...   17/09/2025
# 169                                               None   30/09/2025
# 170  Chính sách thưởng hấp dẫn: thưởng năm, ngày lễ...   31/10/2025
# 171  Laptop, Chế độ bảo hiểm, Du Lịch, Phụ cấp, Chế...   09/10/2025
#
#     source_site search_keyword                 scraped_at scraped_date
# 0     123job.vn   data analyst 2025-10-01 15:52:45.230623   2025-10-01
# 1     123job.vn   data analyst 2025-10-01 15:52:42.696140   2025-10-01
# 2     123job.vn   data analyst 2025-10-01 15:52:40.113075   2025-10-01
# 3     123job.vn   data analyst 2025-10-01 15:52:38.061145   2025-10-01
# 4     123job.vn   data analyst 2025-10-01 15:52:35.125877   2025-10-01
# ..          ...            ...                        ...          ...
# 167   123job.vn   data analyst 2025-09-27 13:39:39.366144   2025-09-27
# 168   123job.vn   data analyst 2025-09-27 13:39:37.545471   2025-09-27
# 169   123job.vn   data analyst 2025-09-27 13:39:35.574948   2025-09-27
# 170   123job.vn   data analyst 2025-09-27 13:39:33.325092   2025-09-27
# 171   123job.vn   data analyst 2025-09-27 13:39:30.452208   2025-09-27
#
# [172 rows x 18 columns]
